# %% [markdown]
# # Fish Diffusion
# <div style="display: flex; justify-content: center;">
# <img alt="LOGO" src="https://cdn.jsdelivr.net/gh/fishaudio/fish-diffusion@main/images/logo_512x512.png" width="256" height="256" />
# </div>
#
# <style>
#   a {
#     margin-right: 16px;
#   }
#   div {
#     margin-top: 16px;
#   }
# </style>
# <div style="display: flex; justify-content: center; margin-bottom: 20px; ">
# <a href="https://discord.gg/wbYSRBrW2E">
# <img alt="Discord" src="https://img.shields.io/discord/1044927142900809739?color=%23738ADB&label=Discord&logo=discord&logoColor=white&style=flat-square"/>
# </a>
#
# <a href="https://huggingface.co/spaces/fishaudio/fish-diffusion">
# <img alt="Hugging Face" src="https://img.shields.io/badge/🤗%20Spaces-HiFiSinger-blue.svg?style=flat-square"/>
# </a>
#
# <a target="_blank" href="https://colab.research.google.com/github/fishaudio/fish-diffusion/blob/main/notebooks/train.ipynb">
# <img alt="Open In Colab" src="https://img.shields.io/static/v1?label=Colab&message=Notebook&color=F9AB00&logo=googlecolab&style=flat-square"/>
# </a>
# </div>
#
# </div>

# %% [markdown]
# ## Terms of Use for Fish Diffusion
#
# 1. Obtaining Authorization and Intellectual Property Infringement: The user is solely accountable for acquiring the necessary authorization for any datasets utilized in their training process and assumes full responsibility for any infringement issues arising from the utilization of the input source. Fish Diffusion and its developers disclaim all responsibility for any complications that may emerge due to the utilization of unauthorized datasets.
#
# 2. Proper Attribution: Any derivative works based on Fish Diffusion must explicitly acknowledge the project and its license. In the event of distributing Fish Diffusion's code or disseminating results generated by this project, the user is obliged to cite the original author and source code (Fish Diffusion).
#
# 3. Audiovisual Content and AI-generated Disclosure: All derivative works created using Fish Diffusion, including audio or video materials, must explicitly acknowledge the utilization of the Fish Diffusion project and declare that the content is AI-generated. If incorporating videos or audio published by third parties, the original links must be furnished.
#
# 4. Agreement to Terms: By persisting in the use of Fish Diffusion, the user unequivocally consents to the terms and conditions delineated in this document. Neither Fish Diffusion nor its developers shall be held liable for any subsequent difficulties that may transpire.

# %%
#@title ## Agreement
i_agree_the_terms_above = False #@param {type:"boolean"}

if i_agree_the_terms_above is False:
  raise Exception("You need to agree with the terms to continue.")

# %% [markdown]
# ## Environment Setup

# %% [markdown]
# ### Check GPU

# %%
#@title
import torch
cuda_available = torch.cuda.is_available()
if cuda_available is False:
  raise Exception("CUDA is not available, please change instance type.")

for i in range(torch.cuda.device_count()):
  print(f"GPU {i}: {torch.cuda.get_device_name(i)} detected.")

print("-" * 20)

# !nvidia-smi
# Out:
# GPU 0: NVIDIA A100-SXM4-40GB detected.
# --------------------
# Wed Oct 29 16:09:20 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0             47W /  400W |       5MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ### Configure Environment
# You may skip this section if you have correct environment (fish_diffusion) installed

# %% [markdown]
# #### Install Conda

# %%
#@title
# %%bash
mkdir /content/env
MINICONDA_INSTALLER_SCRIPT=Miniconda3-py310_23.1.0-1-Linux-x86_64.sh
MINICONDA_PREFIX=/content/env
wget -q --show-progress https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
chmod +x $MINICONDA_INSTALLER_SCRIPT
./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/content/env
# Unpacking payload ...
#
# Installing base environment...
#
#
# Downloading and Extracting Packages
#
#
# Downloading and Extracting Packages
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3:
MB    | ########3  |  84%
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 430 KB    | 3          |   4%
# libnsl-2.0.0         | 31 KB     | #####1     |  52%
#
#
#
#
#
#
#
#
#
# sqlite-3.50.2        | 1.1 MB    | 1          |   1%
#
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 262 KB    | 6          |   6%
#
#
#
#
#
#
#
#
#
#
#
# ncurses-6.5          | 1.1 MB    | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 116 KB    | #3         |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 127 KB    | #2         |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pip-25.2             | 1.1 MB    | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.4         | 141 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-xorgproto-2024. | 580 KB    | 2          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.19       | 24.5 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.19       | 24.5 MB   | 8          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
# pip-25.2             | 1.1 MB    | #1         |  11%
#
#
#
#
#
#
#
# xorg-libx11-1.8.12   | 895 KB    | ########## | 100%
#
#
#
#
#
#
#
# xorg-libx11-1.8.12   | 895 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.19       | 24.5 MB   | #7         |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
# pip-25.2             | 1.1 MB    | #######3   |  74%
# libnsl-2.0.0         | 31 KB     | ########## | 100%
# libnsl-2.0.0         | 31 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.19       | 24.5 MB   | ##5        |  25%
#
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 262 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 262 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 430 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 430 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.19       | 24.5 MB   | ####2      |  42%
#
#
#
#
#
#
#
#
#
# sqlite-3.50.2        | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# sqlite-3.50.2        | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.19       | 24.5 MB   | #####7     |  57%
#
#
#
#
# tk-8.6.15            | 3.4 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.19       | 24.5 MB   | #######4   |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 127 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 127 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.19       | 24.5 MB   | ########7  |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.19       | 24.5 MB   | #########9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-xorgproto-2024. | 580 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xorg-xorgproto-2024. | 580 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 116 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 116 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# setuptools-80.9.0    | 1.4 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# setuptools-80.9.0    | 1.4 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
# pip-25.2             | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# ncurses-6.5          | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# ncurses-6.5          | 1.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.19       | 24.5 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# #
# # To activate this environment, use
# #
# #     $ conda activate fish_diffusion
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 25.9.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=25.9.1

# %% [markdown]
# #### Clone Repo

# %%
#@title
import os

if os.path.exists("/content/fish-diffusion"):
  print("The repo already exists, skipping")
else:
  # !git clone https://github.com/gdoscher/MARGOT /content/fish-diffusion
# Out:
# Cloning into '/content/fish-diffusion'...
# remote: Enumerating objects: 4379, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 4379 (delta 3), reused 10 (delta 3), pack-reused 4365 (from 1)
# Receiving objects: 100% (4379/4379), 62.46 MiB | 46.55 MiB/s, done.
# Resolving deltas: 100% (2703/2703), done.

# %% [markdown]
# #### Install Dependencies
# Note, this error message is fine:
# `Authorization error accessing https://download.pytorch.org/whl/cu118/wheel/`

# %%
#@title
# %cd /content/fish-diffusion
# !source /content/env/bin/activate;\
conda activate fish_diffusion;\
curl -sSL https://raw.githubusercontent.com/pdm-project/pdm/main/install-pdm.py | python3 -;\
/root/.local/bin/pdm sync;
# Out:
# Streaming output truncated to the last 5000 lines.
#   ⠋ Installing safetensors 0.3.3...
#   ⠋ Installing scikit-learn 1.3.1...
#   ⠋ Installing scipy 1.9.3...
#   ⠋ Installing sentencepiece 0.1.99...
#   ⠋ Installing sentry-sdk 1.31.0...
#   ⠋ Installing setproctitle 1.3.2...
#
#   ✔ Install pyyaml 6.0.1 successful
#     Installing nvidia-cublas-cu12 12.6.4.1...   Downloading... 100%
#   ⠹ Installing nvidia-cudnn-cu12 9.5.1.17...    Downloading...  59%
#     Installing nvidia-cusparse-cu12 12.5.4.2... Downloading... 100%
#     Installing nvidia-nccl-cu12 2.26.2...       Downloading... 100%
#     Installing pyarrow 13.0.0...                Downloading... 100%
#     Installing pytz 2023.3.post1...             Downloading... 100%
#   ⠹ Installing pyworld 0.3.4...                 Building...
#     Installing pyyaml 6.0.1...                  Downloading... 100%
#   ⠹ Installing regex 2023.8.8...
#   ⠹ Installing rpds-py 0.10.3...
#   ⠹ Installing safetensors 0.3.3...
#   ⠹ Installing scikit-learn 1.3.1...
#   ⠹ Installing scipy 1.9.3...
#   ⠹ Installing sentencepiece 0.1.99...
#   ⠹ Installing sentry-sdk 1.31.0...
#   ⠹ Installing setproctitle 1.3.2...
#
#     Installing nvidia-cublas-cu12 12.6.4.1...   Downloading... 100%
#   ⠹ Installing nvidia-cudnn-cu12 9.5.1.17...    Downloading...  59%
#     Installing nvidia-cusparse-cu12 12.5.4.2... Downloading... 100%
#     Installing nvidia-nccl-cu12 2.26.2...       Downloading... 100%
#     Installing pyarrow 13.0.0...                Downloading... 100%
#     Installing pytz 2023.3.post1...             Downloading... 100%
#   ⠹ Installing pyworld 0.3.4...                 Building...
#   ⠹ Installing regex 2023.8.8...
#   ⠹ Installing rpds-py 0.10.3...
#   ⠹ Installing safetensors 0.3.3...
#   ⠹ Installing scikit-learn 1.3.1...
#   ⠹ Installing scipy 1.9.3...
#   ⠹ Installing sentencepiece 0.1.99...
#   ⠹ Installing sentry-sdk 1.31.0...
#   ⠹ Installing setproctitle 1.3.2...
#
#     Installing nvidia-cublas-cu12 12.6.4.1...   Downloading... 100%
#   ⠼ Installing nvidia-cudnn-cu12 9.5.1.17...    Downloading...  59%
#     Installing nvidia-cusparse-cu12 12.5.4.2... Downloading... 100%
#     Installing nvidia-nccl-cu12 2.26.2...       Downloading... 100%
#     Installing pyarrow 13.0.0...                Downloading... 100%
#     Installing pytz 2023.3.post1...             Downloading... 100%
#   ⠼ Installing pyworld 0.3.4...                 Building...
#   ⠼ Installing regex 2023.8.8...
#   ⠼ Installing rpds-py 0.10.3...
#   ⠼ Installing safetensors 0.3.3...
#   ⠼ Installing scikit-learn 1.3.1...
#   ⠼ Installing scipy 1.9.3...
#   ⠼ Installing sentencepiece 0.1.99...
#   ⠼ Installing sentry-sdk 1.31.0...
#   ⠼ Installing setproctitle 1.3.2...
#   ⠼ Installing six 1.16.0...
#
#   ✔ Install nvidia-cusparse-cu12 12.5.4.2 successful
#     Installing nvidia-cublas-cu12 12.6.4.1...   Downloading... 100%
#   ⠴ Installing nvidia-cudnn-cu12 9.5.1.17...    Downloading...  60%
#     Installing nvidia-cusparse-cu12 12.5.4.2... Downloading... 100%
#     Installing nvidia-nccl-cu12 2.26.2...       Downloading... 100%
#     Installing pyarrow 13.0.0...                Downloading... 100%
#     Installing pytz 2023.3.post1...             Downloading... 100%
#   ⠴ Installing pyworld 0.3.4...                 Building...
#   ⠴ Installing regex 2023.8.8...
#   ⠴ Installing rpds-py 0.10.3...
#   ⠴ Installing safetensors 0.3.3...
#   ⠴ Installing scikit-learn 1.3.1...
#   ⠴ Installing scipy 1.9.3...
#   ⠴ Installing sentencepiece 0.1.99...
#   ⠴ Installing sentry-sdk 1.31.0...
#   ⠴ Installing setproctitle 1.3.2...
#   ⠴ Installing six 1.16.0...
#
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠦ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  60%
#     Installing nvidia-nccl-cu12 2.26.2...     Downloading... 100%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#     Installing pytz 2023.3.post1...           Downloading... 100%
#   ⠦ Installing pyworld 0.3.4...               Building...
#   ⠦ Installing regex 2023.8.8...
#   ⠦ Installing rpds-py 0.10.3...
#   ⠦ Installing safetensors 0.3.3...
#   ⠦ Installing scikit-learn 1.3.1...
#   ⠦ Installing scipy 1.9.3...
#   ⠦ Installing sentencepiece 0.1.99...
#   ⠦ Installing sentry-sdk 1.31.0...
#   ⠦ Installing setproctitle 1.3.2...
#   ⠦ Installing six 1.16.0...
#
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠧ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  60%
#     Installing nvidia-nccl-cu12 2.26.2...     Downloading... 100%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#     Installing pytz 2023.3.post1...           Downloading... 100%
#   ⠧ Installing pyworld 0.3.4...               Building...
#   ⠧ Installing regex 2023.8.8...
#   ⠧ Installing rpds-py 0.10.3...
#   ⠧ Installing safetensors 0.3.3...
#   ⠧ Installing scikit-learn 1.3.1...
#   ⠧ Installing scipy 1.9.3...
#   ⠧ Installing sentencepiece 0.1.99...
#   ⠧ Installing sentry-sdk 1.31.0...
#   ⠧ Installing setproctitle 1.3.2...
#   ⠧ Installing six 1.16.0...
#   ⠧ Installing smmap 5.0.1...
#
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠋ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  61%
#     Installing nvidia-nccl-cu12 2.26.2...     Downloading... 100%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#     Installing pytz 2023.3.post1...           Downloading... 100%
#   ⠋ Installing pyworld 0.3.4...               Building...
#   ⠋ Installing regex 2023.8.8...
#   ⠋ Installing rpds-py 0.10.3...
#   ⠋ Installing safetensors 0.3.3...
#   ⠋ Installing scikit-learn 1.3.1...
#   ⠋ Installing scipy 1.9.3...
#   ⠋ Installing sentencepiece 0.1.99...
#   ⠋ Installing sentry-sdk 1.31.0...
#   ⠋ Installing setproctitle 1.3.2...
#   ⠋ Installing six 1.16.0...
#   ⠋ Installing smmap 5.0.1...
#
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠼ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  61%
#     Installing nvidia-nccl-cu12 2.26.2...     Downloading... 100%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#     Installing pytz 2023.3.post1...           Downloading... 100%
#   ⠼ Installing pyworld 0.3.4...               Building...
#   ⠼ Installing regex 2023.8.8...
#   ⠼ Installing rpds-py 0.10.3...
#   ⠼ Installing safetensors 0.3.3...
#   ⠼ Installing scikit-learn 1.3.1...
#   ⠼ Installing scipy 1.9.3...
#   ⠼ Installing sentencepiece 0.1.99...
#   ⠼ Installing sentry-sdk 1.31.0...
#   ⠼ Installing setproctitle 1.3.2...
#   ⠼ Installing six 1.16.0...
#   ⠼ Installing smmap 5.0.1...
#
#   ✔ Install nvidia-nccl-cu12 2.26.2 successful
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠦ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  61%
#     Installing nvidia-nccl-cu12 2.26.2...     Downloading... 100%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#     Installing pytz 2023.3.post1...           Downloading... 100%
#   ⠦ Installing pyworld 0.3.4...               Building...
#   ⠦ Installing regex 2023.8.8...
#   ⠦ Installing rpds-py 0.10.3...
#   ⠦ Installing safetensors 0.3.3...
#   ⠦ Installing scikit-learn 1.3.1...
#   ⠦ Installing scipy 1.9.3...
#   ⠦ Installing sentencepiece 0.1.99...
#   ⠦ Installing sentry-sdk 1.31.0...
#   ⠦ Installing setproctitle 1.3.2...
#     Installing six 1.16.0...                  Downloading... 100%
#   ⠦ Installing smmap 5.0.1...
#
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠦ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  61%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#     Installing pytz 2023.3.post1...           Downloading... 100%
#   ⠦ Installing pyworld 0.3.4...               Building...
#   ⠦ Installing regex 2023.8.8...
#   ⠦ Installing rpds-py 0.10.3...
#   ⠦ Installing safetensors 0.3.3...
#   ⠦ Installing scikit-learn 1.3.1...
#   ⠦ Installing scipy 1.9.3...
#   ⠦ Installing sentencepiece 0.1.99...
#   ⠦ Installing sentry-sdk 1.31.0...
#   ⠦ Installing setproctitle 1.3.2...
#     Installing six 1.16.0...                  Downloading... 100%
#   ⠦ Installing smmap 5.0.1...
#
#   ✔ Install six 1.16.0 successful
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠦ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  62%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#     Installing pytz 2023.3.post1...           Downloading... 100%
#   ⠦ Installing pyworld 0.3.4...               Building...
#   ⠦ Installing regex 2023.8.8...
#   ⠦ Installing rpds-py 0.10.3...
#   ⠦ Installing safetensors 0.3.3...
#   ⠦ Installing scikit-learn 1.3.1...
#   ⠦ Installing scipy 1.9.3...
#   ⠦ Installing sentencepiece 0.1.99...
#   ⠦ Installing sentry-sdk 1.31.0...
#   ⠦ Installing setproctitle 1.3.2...
#     Installing six 1.16.0...                  Downloading... 100%
#   ⠦ Installing smmap 5.0.1...
#   ⠦ Installing sniffio 1.3.0...
#
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠧ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  62%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#     Installing pytz 2023.3.post1...           Downloading... 100%
#   ⠧ Installing pyworld 0.3.4...               Building...
#   ⠧ Installing regex 2023.8.8...
#   ⠧ Installing rpds-py 0.10.3...
#   ⠧ Installing safetensors 0.3.3...
#   ⠧ Installing scikit-learn 1.3.1...
#   ⠧ Installing scipy 1.9.3...
#   ⠧ Installing sentencepiece 0.1.99...
#   ⠧ Installing sentry-sdk 1.31.0...
#   ⠧ Installing setproctitle 1.3.2...
#   ⠧ Installing smmap 5.0.1...
#   ⠧ Installing sniffio 1.3.0...
#
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠧ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  62%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#     Installing pytz 2023.3.post1...           Downloading... 100%
#   ⠧ Installing pyworld 0.3.4...               Building...
#   ⠧ Installing regex 2023.8.8...
#   ⠧ Installing rpds-py 0.10.3...
#   ⠧ Installing safetensors 0.3.3...
#   ⠧ Installing scikit-learn 1.3.1...
#   ⠧ Installing scipy 1.9.3...
#   ⠧ Installing sentencepiece 0.1.99...
#   ⠧ Installing sentry-sdk 1.31.0...
#   ⠧ Installing setproctitle 1.3.2...
#   ⠧ Installing smmap 5.0.1...
#   ⠧ Installing sniffio 1.3.0...
#   ⠧ Installing snowballstemmer 2.2.0...
#
#   ✔ Install pytz 2023.3.post1 successful
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠏ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  62%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#     Installing pytz 2023.3.post1...           Downloading... 100%
#   ⠏ Installing pyworld 0.3.4...               Building...
#   ⠏ Installing regex 2023.8.8...
#   ⠏ Installing rpds-py 0.10.3...
#   ⠏ Installing safetensors 0.3.3...
#   ⠏ Installing scikit-learn 1.3.1...
#   ⠏ Installing scipy 1.9.3...
#   ⠏ Installing sentencepiece 0.1.99...
#   ⠏ Installing sentry-sdk 1.31.0...
#   ⠏ Installing setproctitle 1.3.2...
#   ⠏ Installing smmap 5.0.1...
#   ⠏ Installing sniffio 1.3.0...
#   ⠏ Installing snowballstemmer 2.2.0...
#
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠏ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  62%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#   ⠏ Installing pyworld 0.3.4...               Building...
#   ⠏ Installing regex 2023.8.8...
#   ⠏ Installing rpds-py 0.10.3...
#   ⠏ Installing safetensors 0.3.3...
#   ⠏ Installing scikit-learn 1.3.1...
#   ⠏ Installing scipy 1.9.3...
#   ⠏ Installing sentencepiece 0.1.99...
#   ⠏ Installing sentry-sdk 1.31.0...
#   ⠏ Installing setproctitle 1.3.2...
#   ⠏ Installing smmap 5.0.1...
#   ⠏ Installing sniffio 1.3.0...
#   ⠏ Installing snowballstemmer 2.2.0...
#
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠋ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  62%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#   ⠋ Installing pyworld 0.3.4...               Building...
#   ⠋ Installing regex 2023.8.8...
#   ⠋ Installing rpds-py 0.10.3...
#   ⠋ Installing safetensors 0.3.3...
#   ⠋ Installing scikit-learn 1.3.1...
#   ⠋ Installing scipy 1.9.3...
#   ⠋ Installing sentencepiece 0.1.99...
#     Installing sentry-sdk 1.31.0...           Downloading... 100%
#   ⠋ Installing setproctitle 1.3.2...
#     Installing smmap 5.0.1...                 Downloading... 100%
#   ⠋ Installing sniffio 1.3.0...
#   ⠋ Installing snowballstemmer 2.2.0...
#   ⠋ Installing soundfile 0.12.1...
#
#   ✔ Install smmap 5.0.1 successful
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠙ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  62%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#   ⠙ Installing pyworld 0.3.4...               Building...
#   ⠙ Installing regex 2023.8.8...
#   ⠙ Installing rpds-py 0.10.3...
#   ⠙ Installing safetensors 0.3.3...
#   ⠙ Installing scikit-learn 1.3.1...
#   ⠙ Installing scipy 1.9.3...
#   ⠙ Installing sentencepiece 0.1.99...
#     Installing sentry-sdk 1.31.0...           Downloading... 100%
#   ⠙ Installing setproctitle 1.3.2...
#     Installing smmap 5.0.1...                 Downloading... 100%
#   ⠙ Installing sniffio 1.3.0...
#   ⠙ Installing snowballstemmer 2.2.0...
#   ⠙ Installing soundfile 0.12.1...
#
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠙ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  62%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#   ⠙ Installing pyworld 0.3.4...               Building...
#   ⠙ Installing regex 2023.8.8...
#   ⠙ Installing rpds-py 0.10.3...
#   ⠙ Installing safetensors 0.3.3...
#   ⠙ Installing scikit-learn 1.3.1...
#   ⠙ Installing scipy 1.9.3...
#   ⠙ Installing sentencepiece 0.1.99...
#     Installing sentry-sdk 1.31.0...           Downloading... 100%
#   ⠙ Installing setproctitle 1.3.2...
#   ⠙ Installing sniffio 1.3.0...
#   ⠙ Installing snowballstemmer 2.2.0...
#   ⠙ Installing soundfile 0.12.1...
#
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠼ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  62%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#   ⠼ Installing pyworld 0.3.4...               Building...
#   ⠼ Installing regex 2023.8.8...
#   ⠼ Installing rpds-py 0.10.3...
#   ⠼ Installing safetensors 0.3.3...
#   ⠼ Installing scikit-learn 1.3.1...
#   ⠼ Installing scipy 1.9.3...
#   ⠼ Installing sentencepiece 0.1.99...
#     Installing sentry-sdk 1.31.0...           Downloading... 100%
#   ⠼ Installing setproctitle 1.3.2...
#   ⠼ Installing sniffio 1.3.0...
#   ⠼ Installing snowballstemmer 2.2.0...
#   ⠼ Installing soundfile 0.12.1...
#   ⠼ Installing soupsieve 2.5...
#
#   ✔ Install sentry-sdk 1.31.0 successful
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠼ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  63%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#   ⠼ Installing pyworld 0.3.4...               Building...
#   ⠼ Installing regex 2023.8.8...
#   ⠼ Installing rpds-py 0.10.3...
#   ⠼ Installing safetensors 0.3.3...
#   ⠼ Installing scikit-learn 1.3.1...
#   ⠼ Installing scipy 1.9.3...
#   ⠼ Installing sentencepiece 0.1.99...
#     Installing sentry-sdk 1.31.0...           Downloading... 100%
#   ⠼ Installing setproctitle 1.3.2...
#   ⠼ Installing sniffio 1.3.0...
#   ⠼ Installing snowballstemmer 2.2.0...
#   ⠼ Installing soundfile 0.12.1...
#   ⠼ Installing soupsieve 2.5...
#
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠴ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  63%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#   ⠴ Installing pyworld 0.3.4...               Building...
#   ⠴ Installing regex 2023.8.8...
#   ⠴ Installing rpds-py 0.10.3...
#   ⠴ Installing safetensors 0.3.3...
#   ⠴ Installing scikit-learn 1.3.1...
#   ⠴ Installing scipy 1.9.3...
#   ⠴ Installing sentencepiece 0.1.99...
#   ⠴ Installing setproctitle 1.3.2...
#   ⠴ Installing sniffio 1.3.0...
#   ⠴ Installing snowballstemmer 2.2.0...
#   ⠴ Installing soundfile 0.12.1...
#   ⠴ Installing soupsieve 2.5...
#
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠧ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  63%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#   ⠧ Installing pyworld 0.3.4...               Building...
#   ⠧ Installing regex 2023.8.8...
#   ⠧ Installing rpds-py 0.10.3...
#   ⠧ Installing safetensors 0.3.3...
#   ⠧ Installing scikit-learn 1.3.1...
#   ⠧ Installing scipy 1.9.3...
#   ⠧ Installing sentencepiece 0.1.99...
#   ⠧ Installing setproctitle 1.3.2...
#   ⠧ Installing sniffio 1.3.0...
#   ⠧ Installing snowballstemmer 2.2.0...
#   ⠧ Installing soundfile 0.12.1...
#   ⠧ Installing soupsieve 2.5...
#   ⠧ Installing sphinx 7.2.6...
#
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠋ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  64%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#   ⠋ Installing pyworld 0.3.4...               Building...
#   ⠋ Installing regex 2023.8.8...
#   ⠋ Installing rpds-py 0.10.3...
#   ⠋ Installing safetensors 0.3.3...
#   ⠋ Installing scikit-learn 1.3.1...
#   ⠋ Installing scipy 1.9.3...
#   ⠋ Installing sentencepiece 0.1.99...
#   ⠋ Installing setproctitle 1.3.2...
#   ⠋ Installing sniffio 1.3.0...
#   ⠋ Installing snowballstemmer 2.2.0...
#   ⠋ Installing soundfile 0.12.1...
#   ⠋ Installing soupsieve 2.5...
#   ⠋ Installing sphinx 7.2.6...
#
#   ✔ Install sniffio 1.3.0 successful
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠹ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  64%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#   ⠹ Installing pyworld 0.3.4...               Building...
#   ⠹ Installing regex 2023.8.8...
#   ⠹ Installing rpds-py 0.10.3...
#   ⠹ Installing safetensors 0.3.3...
#   ⠹ Installing scikit-learn 1.3.1...
#   ⠹ Installing scipy 1.9.3...
#   ⠹ Installing sentencepiece 0.1.99...
#   ⠹ Installing setproctitle 1.3.2...
#     Installing sniffio 1.3.0...               Downloading... 100%
#     Installing snowballstemmer 2.2.0...       Downloading... 100%
#   ⠹ Installing soundfile 0.12.1...
#   ⠹ Installing soupsieve 2.5...
#   ⠹ Installing sphinx 7.2.6...
#
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠹ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  64%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#   ⠹ Installing pyworld 0.3.4...               Building...
#   ⠹ Installing regex 2023.8.8...
#   ⠹ Installing rpds-py 0.10.3...
#   ⠹ Installing safetensors 0.3.3...
#   ⠹ Installing scikit-learn 1.3.1...
#   ⠹ Installing scipy 1.9.3...
#   ⠹ Installing sentencepiece 0.1.99...
#   ⠹ Installing setproctitle 1.3.2...
#     Installing snowballstemmer 2.2.0...       Downloading... 100%
#   ⠹ Installing soundfile 0.12.1...
#   ⠹ Installing soupsieve 2.5...
#   ⠹ Installing sphinx 7.2.6...
#
#   ✔ Install snowballstemmer 2.2.0 successful
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠸ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  64%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#   ⠸ Installing pyworld 0.3.4...               Building...
#   ⠸ Installing regex 2023.8.8...
#   ⠸ Installing rpds-py 0.10.3...
#   ⠸ Installing safetensors 0.3.3...
#   ⠸ Installing scikit-learn 1.3.1...
#   ⠸ Installing scipy 1.9.3...
#   ⠸ Installing sentencepiece 0.1.99...
#   ⠸ Installing setproctitle 1.3.2...
#     Installing snowballstemmer 2.2.0...       Downloading... 100%
#   ⠸ Installing soundfile 0.12.1...
#   ⠸ Installing soupsieve 2.5...
#   ⠸ Installing sphinx 7.2.6...
#   ⠸ Installing sphinx-autobuild 2021.3.14...
#
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠸ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  64%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#   ⠸ Installing pyworld 0.3.4...               Building...
#   ⠸ Installing regex 2023.8.8...
#   ⠸ Installing rpds-py 0.10.3...
#   ⠸ Installing safetensors 0.3.3...
#   ⠸ Installing scikit-learn 1.3.1...
#   ⠸ Installing scipy 1.9.3...
#   ⠸ Installing sentencepiece 0.1.99...
#   ⠸ Installing setproctitle 1.3.2...
#   ⠸ Installing soundfile 0.12.1...
#   ⠸ Installing soupsieve 2.5...
#   ⠸ Installing sphinx 7.2.6...
#   ⠸ Installing sphinx-autobuild 2021.3.14...
#
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠼ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  64%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#   ⠼ Installing pyworld 0.3.4...               Building...
#   ⠼ Installing regex 2023.8.8...
#   ⠼ Installing rpds-py 0.10.3...
#   ⠼ Installing safetensors 0.3.3...
#   ⠼ Installing scikit-learn 1.3.1...
#   ⠼ Installing scipy 1.9.3...
#   ⠼ Installing sentencepiece 0.1.99...
#   ⠼ Installing setproctitle 1.3.2...
#   ⠼ Installing soundfile 0.12.1...
#   ⠼ Installing soupsieve 2.5...
#   ⠼ Installing sphinx 7.2.6...
#   ⠼ Installing sphinx-autobuild 2021.3.14...
#   ⠼ Installing sphinx-basic-ng 1.0.0b2...
#
#   ✔ Install soupsieve 2.5 successful
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠦ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  65%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#   ⠦ Installing pyworld 0.3.4...               Building...
#   ⠦ Installing regex 2023.8.8...
#   ⠦ Installing rpds-py 0.10.3...
#   ⠦ Installing safetensors 0.3.3...
#   ⠦ Installing scikit-learn 1.3.1...
#   ⠦ Installing scipy 1.9.3...
#   ⠦ Installing sentencepiece 0.1.99...
#   ⠦ Installing setproctitle 1.3.2...
#   ⠦ Installing soundfile 0.12.1...
#     Installing soupsieve 2.5...               Downloading... 100%
#   ⠦ Installing sphinx 7.2.6...
#   ⠦ Installing sphinx-autobuild 2021.3.14...
#   ⠦ Installing sphinx-basic-ng 1.0.0b2...
#
#     Installing nvidia-cublas-cu12 12.6.4.1... Downloading... 100%
#   ⠦ Installing nvidia-cudnn-cu12 9.5.1.17...  Downloading...  65%
#     Installing pyarrow 13.0.0...              Downloading... 100%
#   ⠦ Installing pyworld 0.3.4...               Building...
#   ⠦ Installing regex 2023.8.8...
#   ⠦ Installing rpds-py 0.10.3...
#   ⠦ Installing safetensors 0.3.3...
#   ⠦ Installing scikit-learn 1.3.1...
#   ⠦ Installing scipy 1.9.3...
#   ⠦ Installing sentencepiece 0.1.99...
#   ⠦ Installing setproctitle 1.3.2...
#   ⠦ Installing soundfile 0.12.1...
#   ⠦ Installing sphinx 7.2.6...
#   ⠦ Installing sphinx-autobuild 2021.3.14...
#   ⠦ Installing sphinx-basic-ng 1.0.0b2...
#
#     Installing nvidia-cublas-cu12 12.6.4.1...   Downloading... 100%
#   ⠧ Installing nvidia-cudnn-cu12 9.5.1.17...    Downloading...  65%
#     Installing pyarrow 13.0.0...                Downloading... 100%
#   ⠧ Installing pyworld 0.3.4...                 Building...
#   ⠧ Installing regex 2023.8.8...
#   ⠧ Installing rpds-py 0.10.3...
#   ⠧ Installing safetensors 0.3.3...
#   ⠧ Installing scikit-learn 1.3.1...
#   ⠧ Installing scipy 1.9.3...
#   ⠧ Installing sentencepiece 0.1.99...
#   ⠧ Installing setproctitle 1.3.2...
#   ⠧ Installing soundfile 0.12.1...
#   ⠧ Installing sphinx 7.2.6...
#   ⠧ Installing sphinx-autobuild 2021.3.14...
#   ⠧ Installing sphinx-basic-ng 1.0.0b2...
#   ⠧ Installing sphinxcontrib-applehelp 1.0.7...
#
#     Installing nvidia-cublas-cu12 12.6.4.1...   Downloading... 100%
#   ⠋ Installing nvidia-cudnn-cu12 9.5.1.17...    Downloading...  65%
#     Installing pyarrow 13.0.0...                Downloading... 100%
#   ⠋ Installing pyworld 0.3.4...                 Building...
#   ⠋ Installing regex 2023.8.8...
#   ⠋ Installing rpds-py 0.10.3...
#   ⠋ Installing safetensors 0.3.3...
#   ⠋ Installing scikit-learn 1.3.1...
#   ⠋ Installing scipy 1.9.3...
#   ⠋ Installing sentencepiece 0.1.99...
#   ⠋ Installing setproctitle 1.3.2...
#     Installing soundfile 0.12.1...              Downloading... 100%
#   ⠋ Installing sphinx 7.2.6...
#   ⠋ Installing sphinx-autobuild 2021.3.14...
#   ⠋ Installing sphinx-basic-ng 1.0.0b2...
#   ⠋ Installing sphinxcontrib-applehelp 1.0.7...
#
#   ✔ Install soundfile 0.12.1 successful
#     Installing nvidia-cublas-cu12 12.6.4.1...   Downloading... 100%
#   ⠸ Installing nvidia-cudnn-cu12 9.5.1.17...    Downloading...  66%
#     Installing pyarrow 13.0.0...                Downloading... 100%
#   ⠸ Installing pyworld 0.3.4...                 Building...
#   ⠸ Installing regex 2023.8.8...
#   ⠸ Installing rpds-py 0.10.3...
#   ⠸ Installing safetensors 0.3.3...
#   ⠸ Installing scikit-learn 1.3.1...
#   ⠸ Installing scipy 1.9.3...
#   ⠸ Installing sentencepiece 0.1.99...
#   ⠸ Installing setproctitle 1.3.2...
#     Installing soundfile 0.12.1...              Downloading... 100%
#   ⠸ Installing sphinx 7.2.6...
#   ⠸ Installing sphinx-autobuild 2021.3.14...
#   ⠸ Installing sphinx-basic-ng 1.0.0b2...
#   ⠸ Installing sphinxcontrib-applehelp 1.0.7...
#
#     Installing nvidia-cublas-cu12 12.6.4.1...   Downloading... 100%
#   ⠸ Installing nvidia-cudnn-cu12 9.5.1.17...    Downloading...  66%
#     Installing pyarrow 13.0.0...                Downloading... 100%
#   ⠸ Installing pyworld 0.3.4...                 Building...
#   ⠸ Installing regex 2023.8.8...
#   ⠸ Installing rpds-py 0.10.3...
#   ⠸ Installing safetensors 0.3.3...
#   ⠸ Installing scikit-learn 1.3.1...
#   ⠸ Installing scipy 1.9.3...
#   ⠸ Installing sentencepiece 0.1.99...
#   ⠸ Installing setproctitle 1.3.2...
#   ⠸ Installing sphinx 7.2.6...
#   ⠸ Installing sphinx-autobuild 2021.3.14...
#   ⠸ Installing sphinx-basic-ng 1.0.0b2...
#   ⠸ Installing sphinxcontrib-applehelp 1.0.7...
#
#     Installing nvidia-cublas-cu12 12.6.4.1...   Downloading... 100%
#   ⠼ Installing nvidia-cudnn-cu12 9.5.1.17...    Downloading...  66%
#     Installing pyarrow 13.0.0...                Downloading... 100%
#   ⠼ Installing pyworld 0.3.4...                 Building...
#   ⠼ Installing regex 2023.8.8...
#   ⠼ Installing rpds-py 0.10.3...
#   ⠼ Installing safetensors 0.3.3...
#   ⠼ Installing scikit-learn 1.3.1...
#   ⠼ Installing scipy 1.9.3...
#   ⠼ Installing sentencepiece 0.1.99...
#   ⠼ Installing setproctitle 1.3.2...
#   ⠼ Installing sphinx 7.2.6...
#   ⠼ Installing sphinx-autobuild 2021.3.14...
#   ⠼ Installing sphinx-basic-ng 1.0.0b2...
#   ⠼ Installing sphinxcontrib-applehelp 1.0.7...
#   ⠼ Installing sphinxcontrib-devhelp 1.0.5...
#
#     Installing nvidia-cublas-cu12 12.6.4.1...   Downloading... 100%
#   ⠧ Installing nvidia-cudnn-cu12 9.5.1.17...    Downloading...  67%
#     Installing pyarrow 13.0.0...                Downloading... 100%
#   ⠧ Installing pyworld 0.3.4...                 Building...
#   ⠧ Installing regex 2023.8.8...
#   ⠧ Installing rpds-py 0.10.3...
#   ⠧ Installing safetensors 0.3.3...
#   ⠧ Installing scikit-learn 1.3.1...
#   ⠧ Installing scipy 1.9.3...
#   ⠧ Installing sentencepiece 0.1.99...
#   ⠧ Installing setproctitle 1.3.2...
#   ⠧ Installing sphinx 7.2.6...
#   ⠧ Installing sphinx-autobuild 2021.3.14...
#     Installing sphinx-basic-ng 1.0.0b2...       Downloading... 100%
#   ⠧ Installing sphinxcontrib-applehelp 1.0.7...
#   ⠧ Installing sphinxcontrib-devhelp 1.0.5...
#
#   ✔ Install sphinx-basic-ng 1.0.0b2 successful
#     Installing nvidia-cublas-cu12 12.6.4.1...   Downloading... 100%
#   ⠇ Installing nvidia-cudnn-cu12 9.5.1.17...    Downloading...  67%
#     Installing pyarrow 13.0.0...                Downloading... 100%
#   ⠇ Installing pyworld 0.3.4...                 Building...
#   ⠇ Installing regex 2023.8.8...
#   ⠇ Installing rpds-py 0.10.3...
#   ⠇ Installing safetensors 0.3.3...
#   ⠇ Installing scikit-learn 1.3.1...
#   ⠇ Installing scipy 1.9.3...
#   ⠇ Installing sentencepiece 0.1.99...
#   ⠇ Installing setproctitle 1.3.2...
#   ⠇ Installing sphinx 7.2.6...
#   ⠇ Installing sphinx-autobuild 2021.3.14...
#     Installing sphinx-basic-ng 1.0.0b2...       Downloading... 100%
#   ⠇ Installing sphinxcontrib-applehelp 1.0.7...
#   ⠇ Installing sphinxcontrib-devhelp 1.0.5...
#
#     Installing nvidia-cublas-cu12 12.6.4.1...   Downloading... 100%
#   ⠏ Installing nvidia-cudnn-cu12 9.5.1.17...    Downloading...  67%
#     Installing pyarrow 13.0.0...                Downloading... 100%
#   ⠏ Installing pyworld 0.3.4...                 Building...
#   ⠏ Installing regex 2023.8.8...
#   ⠏ Installing rpds-py 0.10.3...
#   ⠏ Installing safetensors 0.3.3...
#   ⠏ Installing scikit-learn 1.3.1...
#   ⠏ Installing scipy 1.9.3...
#   ⠏ Installing sentencepiece 0.1.99...
#   ⠏ Installing setproctitle 1.3.2...
#   ⠏ Installing sphinx 7.2.6...
#   ⠏ Installing sphinx-autobuild 2021.3.14...
#   ⠏ Installing sphinxcontrib-applehelp 1.0.7...
#   ⠏ Installing sphinxcontrib-devhelp 1.0.5...
#
#   ✔ Install sphinx-autobuild 2021.3.14 successful
#     Installing nvidia-cublas-cu12 12.6.4.1...   Downloading... 100%
#   ⠋ Installing nvidia-cudnn-cu12 9.5.1.17...    Downloading...  67%
#     Installing pyarrow 13.0.0...                Downloading... 100%
#   ⠋ Installing pyworld 0.3.4...                 Building...
#   ⠋ Installing regex 2023.8.8...
#   ⠋ Installing rpds-py 0.10.3...
#   ⠋ Installing safetensors 0.3.3...
#   ⠋ Installing scikit-learn 1.3.1...
#   ⠋ Installing scipy 1.9.3...
#   ⠋ Installing sentencepiece 0.1.99...
#   ⠋ Installing setproctitle 1.3.2...
#   ⠋ Installing sphinx 7.2.6...
#     Installing sphinx-autobuild 2021.3.14...    Downloading... 100%
#   ⠋ Installing sphinxcontrib-applehelp 1.0.7... Downloading...  20%
#   ⠋ Installing sphinxcontrib-devhelp 1.0.5...
#   ⠋ Installing sphinxcontrib-htmlhelp 2.0.4...
#
#     Installing nvidia-cublas-cu12 12.6.4.1...   Downloading... 100%
#   ⠋ Installing nvidia-cudnn-cu12 9.5.1.17...    Downloading...  67%
#     Installing pyarrow 13.0.0...                Downloading... 100%
#   ⠋ Installing pyworld 0.3.4...                 Building...
#   ⠋ Installing regex 2023.8.8...
#   ⠋ Installing rpds-py 0.10.3...
#   ⠋ Installing safetensors 0.3.3...
#   ⠋ Installing scikit-learn 1.3.1...
#   ⠋ Installing scipy 1.9.3...
#   ⠋ Installing sentencepiece 0.1.99...
#   ⠋ Installing setproctitle 1.3.2...
#   ⠋ Installing sphinx 7.2.6...
#   ⠋ Installing sphinxcontrib-applehelp 1.0.7... Downloading...  27%
#   ⠋ Installing sphinxcontrib-devhelp 1.0.5...
#   ⠋ Installing sphinxcontrib-htmlhelp 2.0.4...
#
#     Installing nvidia-cublas-cu12 12.6.4.1...   Downloading... 100%
#   ⠋ Installing nvidia-cudnn-cu12 9.5.1.17...    Downloading...  67%
#     Installing pyarrow 13.0.0...                Downloading... 100%
#   ⠋ Installing pyworld 0.3.4...                 Building...
#   ⠋ Installing regex 2023.8.8...
#   ⠋ Installing rpds-py 0.10.3...
#   ⠋ Installing safetensors 0.3.3...
#   ⠋ Installing scikit-learn 1.3.1...
#   ⠋ Installing scipy 1.9.3...
#   ⠋ Installing sentencepiece 0.1.99...
#   ⠋ Installing setproctitle 1.3.2...
#   ⠋ Installing sphinx 7.2.6...
#   ⠋ Installing sphinxcontrib-applehelp 1.0.7... Downloading...  89%
#   ⠋ Installing sphinxcontrib-devhelp 1.0.5...
#   ⠋ Installing sphinxcontrib-htmlhelp 2.0.4...
#   ⠋ Installing sphinxcontrib-jsmath 1.0.1...
#
#     Installing nvidia-cublas-cu12 12.6.4.1...   Downloading... 100%
#   ⠼ Installing nvidia-cudnn-cu12 9.5.1.17...    Downloading...  68%
#     Installing pyarrow 13.0.0...                Downloading... 100%
#   ⠼ Installing pyworld 0.3.4...                 Building...
#   ⠼ Installing regex 2023.8.8...
#   ⠼ Installing rpds-py 0.10.3...
#   ⠼ Installing safetensors 0.3.3...
#   ⠼ Installing scikit-learn 1.3.1...
#   ⠼ Installing scipy 1.9.3...
#   ⠼ Installing sentencepiece 0.1.99...
#   ⠼ Installing setproctitle 1.3.2...
#   ⠼ Installing sphinx 7.2.6...
#     Installing sphinxcontrib-applehelp 1.0.7... Downloading... 100%
#   ⠼ Installing sphinxcontrib-devhelp 1.0.5...
#   ⠼ Installing sphinxcontrib-htmlhelp 2.0.4...
#   ⠼ Installing sphinxcontrib-jsmath 1.0.1...
#
#   ✔ Install sphinxcontrib-applehelp 1.0.7 successful
#     Installing nvidia-cublas-cu12 12.6.4.1...   Downloading... 100%
#   ⠴ Installing nvidia-cudnn-cu12 9.5.1.17...    Downloading...  68%
#     Installing pyarrow 13.0.0...                Downloading... 100%
#   ⠴ Installing pyworld 0.3.4...                 Building...
#   ⠴ Installing regex 2023.8.8...
#   ⠴ Installing rpds-py 0.10.3...
#   ⠴ Installing safetensors 0.3.3...
#   ⠴ Installing scikit-learn 1.3.1...
#   ⠴ Installing scipy 1.9.3...
#   ⠴ Installing sentencepiece 0.1.99...
#   ⠴ Installing setproctitle 1.3.2...
#   ⠴ Installing sphinx 7.2.6...
#     Installing sphinxcontrib-applehelp 1.0.7... Downloading... 100%
#   ⠴ Installing sphinxcontrib-devhelp 1.0.5...
#   ⠴ Installing sphinxcontrib-htmlhelp 2.0.4...
#   ⠴ Installing sphinxcontrib-jsmath 1.0.1...
#
#     Installing nvidia-cublas-cu12 12.6.4.1...  Downloading... 100%
#   ⠴ Installing nvidia-cudnn-cu12 9.5.1.17...   Downloading...  68%
#     Installing pyarrow 13.0.0...               Downloading... 100%
#   ⠴ Installing pyworld 0.3.4...                Building...
#   ⠴ Installing regex 2023.8.8...
#   ⠴ Installing rpds-py 0.10.3...
#   ⠴ Installing safetensors 0.3.3...
#   ⠴ Installing scikit-learn 1.3.1...
#   ⠴ Installing scipy 1.9.3...
#   ⠴ Installing sentencepiece 0.1.99...
#   ⠴ Installing setproctitle 1.3.2...
#   ⠴ Installing sphinx 7.2.6...
#   ⠴ Installing sphinxcontrib-devhelp 1.0.5...
#   ⠴ Installing sphinxcontrib-htmlhelp 2.0.4...
#   ⠴ Installing sphinxcontrib-jsmath 1.0.1...
#
#     Installing nvidia-cublas-cu12 12.6.4.1...  Downloading... 100%
#   ⠧ Installing nvidia-cudnn-cu12 9.5.1.17...   Downloading...  68%
#     Installing pyarrow 13.0.0...               Downloading... 100%
#   ⠧ Installing pyworld 0.3.4...                Building...
#   ⠧ Installing regex 2023.8.8...
#   ⠧ Installing rpds-py 0.10.3...
#   ⠧ Installing safetensors 0.3.3...
#   ⠧ Installing scikit-learn 1.3.1...
#   ⠧ Installing scipy 1.9.3...
#   ⠧ Installing sentencepiece 0.1.99...
#   ⠧ Installing setproctitle 1.3.2...
#   ⠧ Installing sphinx 7.2.6...
# ...
#   ⠦ Installing pyworld 0.3.4...              Building...
#   ⠦ Installing torch 2.7.1...                Downloading...   3%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠋ Installing pyworld 0.3.4...              Building...
#   ⠋ Installing torch 2.7.1...                Downloading...   4%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠸ Installing pyworld 0.3.4...              Building...
#   ⠸ Installing torch 2.7.1...                Downloading...   4%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠦ Installing pyworld 0.3.4...              Building...
#   ⠦ Installing torch 2.7.1...                Downloading...   5%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠏ Installing pyworld 0.3.4...              Building...
#   ⠏ Installing torch 2.7.1...                Downloading...   5%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠹ Installing pyworld 0.3.4...              Building...
#   ⠹ Installing torch 2.7.1...                Downloading...   6%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠦ Installing pyworld 0.3.4...              Building...
#   ⠦ Installing torch 2.7.1...                Downloading...   6%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠏ Installing pyworld 0.3.4...              Building...
#   ⠏ Installing torch 2.7.1...                Downloading...   7%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠹ Installing pyworld 0.3.4...              Building...
#   ⠹ Installing torch 2.7.1...                Downloading...   7%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠴ Installing pyworld 0.3.4...              Building...
#   ⠴ Installing torch 2.7.1...                Downloading...   9%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠇ Installing pyworld 0.3.4...              Building...
#   ⠇ Installing torch 2.7.1...                Downloading...  10%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠹ Installing pyworld 0.3.4...              Building...
#   ⠹ Installing torch 2.7.1...                Downloading...  14%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠴ Installing pyworld 0.3.4...              Building...
#   ⠴ Installing torch 2.7.1...                Downloading...  16%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠇ Installing pyworld 0.3.4...              Building...
#   ⠇ Installing torch 2.7.1...                Downloading...  20%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠙ Installing pyworld 0.3.4...              Building...
#   ⠙ Installing torch 2.7.1...                Downloading...  24%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠼ Installing pyworld 0.3.4...              Building...
#   ⠼ Installing torch 2.7.1...                Downloading...  29%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠇ Installing pyworld 0.3.4...              Building...
#   ⠇ Installing torch 2.7.1...                Downloading...  35%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠙ Installing pyworld 0.3.4...              Building...
#   ⠙ Installing torch 2.7.1...                Downloading...  37%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠼ Installing pyworld 0.3.4...              Building...
#   ⠼ Installing torch 2.7.1...                Downloading...  42%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠇ Installing pyworld 0.3.4...              Building...
#   ⠇ Installing torch 2.7.1...                Downloading...  47%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠙ Installing pyworld 0.3.4...              Building...
#   ⠙ Installing torch 2.7.1...                Downloading...  53%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠼ Installing pyworld 0.3.4...              Building...
#   ⠼ Installing torch 2.7.1...                Downloading...  59%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠧ Installing pyworld 0.3.4...              Building...
#   ⠧ Installing torch 2.7.1...                Downloading...  62%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠙ Installing pyworld 0.3.4...              Building...
#   ⠙ Installing torch 2.7.1...                Downloading...  68%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠼ Installing pyworld 0.3.4...              Building...
#   ⠼ Installing torch 2.7.1...                Downloading...  74%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠧ Installing pyworld 0.3.4...              Building...
#   ⠧ Installing torch 2.7.1...                Downloading...  81%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠋ Installing pyworld 0.3.4...              Building...
#   ⠋ Installing torch 2.7.1...                Downloading...  88%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠸ Installing pyworld 0.3.4...              Building...
#   ⠸ Installing torch 2.7.1...                Downloading...  94%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠧ Installing pyworld 0.3.4...              Building...
#     Installing torch 2.7.1...                Downloading... 100%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠋ Installing pyworld 0.3.4...              Building...
#     Installing torch 2.7.1...                Downloading... 100%
#     Installing triton 3.3.1...               Downloading... 100%
#
#   ✔ Install triton 3.3.1 successful
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠹ Installing pyworld 0.3.4...              Building...
#     Installing torch 2.7.1...                Downloading... 100%
#     Installing triton 3.3.1...               Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠹ Installing pyworld 0.3.4...              Building...
#     Installing torch 2.7.1...                Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠸ Installing pyworld 0.3.4...              Building...
#     Installing torch 2.7.1...                Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠦ Installing pyworld 0.3.4...              Building...
#     Installing torch 2.7.1...                Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠏ Installing pyworld 0.3.4...              Building...
#     Installing torch 2.7.1...                Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠸ Installing pyworld 0.3.4...              Building...
#     Installing torch 2.7.1...                Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠦ Installing pyworld 0.3.4...              Building...
#     Installing torch 2.7.1...                Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠏ Installing pyworld 0.3.4...              Building...
#     Installing torch 2.7.1...                Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠹ Installing pyworld 0.3.4...              Building...
#     Installing torch 2.7.1...                Downloading... 100%
#
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠴ Installing pyworld 0.3.4...              Building...
#     Installing torch 2.7.1...                Downloading... 100%
#
#   ✔ Install nvidia-cudnn-cu12 9.5.1.17 successful
#     Installing nvidia-cudnn-cu12 9.5.1.17... Downloading... 100%
#   ⠇ Installing pyworld 0.3.4...              Building...
#     Installing torch 2.7.1...                Downloading... 100%
#
#   ⠇ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠏ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠹ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠴ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠇ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠙ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠼ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠇ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠙ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠼ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠧ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠋ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠸ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠧ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠋ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠸ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠦ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠏ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠹ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠦ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠏ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠹ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠴ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠇ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠙ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠴ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠇ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠙ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠼ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠧ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠋ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠼ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠧ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠋ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠸ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠦ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠏ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ⠸ Installing pyworld 0.3.4... Building...
#     Installing torch 2.7.1...   Downloading... 100%
#
#   ✔ Install pyworld 0.3.4 successful
#   ⠴ Installing pyworld 0.3.4...
#     Installing torch 2.7.1...   Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#     Installing torch 2.7.1... Downloading... 100%
#
#   ✔ Install torch 2.7.1 successful
#     Installing torch 2.7.1... Downloading... 100%
#
#
#
#   ⠹ Installing fish-diffusion 2.2.0... Building...
#
#   ⠴ Installing fish-diffusion 2.2.0... Building...
#
#   ⠇ Installing fish-diffusion 2.2.0... Building...
#
#   ⠹ Installing fish-diffusion 2.2.0... Building...
#
#   ⠴ Installing fish-diffusion 2.2.0... Building...
#
#   ✔ Install fish-diffusion 2.2.0 successful
#   ⠧ Installing fish-diffusion 2.2.0...
#
#
#
#   0:03:38 🎉 All complete! 248/248

# %% [markdown]
# ## Vocoder preparation
# This section is used to prepare NSF-HiFiGAN for Diffusion (DiffSVC) training. It's optional in HiFiSinger.

# %%
#@title
# %cd /content/fish-diffusion
# !source /content/env/bin/activate;\
conda activate fish_diffusion;\
python tools/download_nsf_hifigan.py --agree-license
# Out:
# /content/fish-diffusion
# 2025-10-29 16:14:24.388 | INFO     | __main__:main:68 - NSF HifiGan (FishAudioStableV1) is released under the CC BY-NC-SA 4.0 license.
# 2025-10-29 16:14:24.388 | INFO     | __main__:main:71 - See https://github.com/fishaudio/fish-diffusion/releases for more information.
# 2025-10-29 16:14:24.388 | INFO     | __main__:main:78 - You already argee the license by passing --agree-license option.
# 2025-10-29 16:14:24.388 | INFO     | __main__:main:87 - Downloading the Vocoder...
# Downloading: 100% 106M/106M [00:01<00:00, 54.8MiB/s]
# 2025-10-29 16:14:26.662 | INFO     | __main__:main:93 - Unzipping the Vocoder...
# 2025-10-29 16:14:27.420 | INFO     | __main__:main:98 - Done.

# %% [markdown]
# ## Dataset Preparation
# Currently, only single speaker-training is supported in this notebook.
#
# ### Option 1
# **You need to split your audios to 5-10 seconds segements before uploading them!!!**.
# To solve disk IO limitation, you need to upload your dataset in zip format with the following structure:
#
# ```shell
# [ZIP ROOT]
# ├───train
# │   ├───xxx1-xxx1.wav
# │   ├───...
# │   └───Lxx-0xx8.wav
# └───valid
#     ├───xx2-0xxx2.wav
#     ├───...
#     └───xxx7-xxx007.wav
# ```
#
# You only need to pick 5-10 samples to the valid folder.
#
# ### Option 2
# If you want the program to do split and pick them automatically, only upload a folder of wavs:
#
# ```shell
# [ZIP ROOT]
# ├───xxx1-xxx1.wav
# ├───...
# └───Lxx-0xx8.wav
# ```

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#@title Preprocess Dataset

import os
import zipfile

#@markdown Do you want the program to download zip from gdrive automatically, instead of upload it by yourself?
download_from_gdrive = True #@param {type:"boolean"}
#@markdown The path of google drive or relative to the `/content`
dataset_path = "Fish Diffusion/opencpop-wavs.zip" #@param {type:"string"}
#@markdown Do you want the program to automatically slice audio into segments?
auto_slice = False #@param {type:"boolean"}
#@markdown Do you want the program to automatically split train and valid set?
auto_pick = True #@param {type:"boolean"}
auto_pick_num = 5 #@param {type:"number"}

if download_from_gdrive:
  from google.colab import drive
  drive.mount('/content/drive/')
  zip_path = os.path.join("/content/drive/MyDrive", dataset_path)
else:
  zip_path = os.path.join("/content", dataset_path)

z = zipfile.ZipFile(zip_path)
files = list(z.namelist())
has_train_folder = any(i.startswith("train") for i in files)
has_valid_folder = any(i.startswith("valid") for i in files)
has_folder = any("/" in i for i in files)

print(f"Has train folder: {has_train_folder}")
print(f"Has valid folder: {has_valid_folder}")
print(f"Has folder: {has_folder}")
print("-" * 20)

# !rm -rf /content/fish-diffusion/dataset

if has_train_folder != has_valid_folder:
  print("Your dataset structure is incorrect, you should have either both train and valid or none of them.")
elif not (has_train_folder and has_valid_folder) and has_folder:
  print("Your dataset structure is incorrect, you shouldn't have any folders in your zip if you don't have both train and valid.")
elif has_folder and not (auto_slice is False and auto_pick is False):
  print("Auto split and auto pick are not available when subfolders exist")
elif has_train_folder and has_valid_folder:
  os.makedirs("/content/fish-diffusion/dataset", exist_ok=True)
  # !unzip -q "{zip_path}" -d /content/fish-diffusion/dataset
  print("OK")
else:
  train_path = "/content/fish-diffusion/dataset/train"
  valid_path = "/content/fish-diffusion/dataset/valid"
  os.makedirs(train_path, exist_ok=True)
  os.makedirs(valid_path, exist_ok=True)

  if auto_slice:
    print("Unzipping")
    raw_path = "/content/fish-diffusion/dataset/raw"
    os.makedirs(raw_path, exist_ok=True)
    # !unzip -q "{zip_path}" -d "{raw_path}"
    print("Unzip completed")

    # Call slicer
    # !/content/env/envs/fish_diffusion/bin/fap slice-audio \
      "{raw_path}" "{train_path}" --top-db 50 --num-workers 4
    print("Audo sliced")
  else:
    print("Unzipping")
    # !unzip -q "{zip_path}" -d "{train_path}"
    print("Unzip completed")

  # !/content/env/envs/fish_diffusion/bin/python \
    /content/fish-diffusion/tools/preprocessing/random_move.py \
    "{train_path}" "{valid_path}" "{auto_pick_num}"

  print("Copied 5 random files to valid folder")
  print("OK")

# %% [markdown]
# ## Choose Your Model

# %%
#@title Model Config
#@markdown It's strongly recommand to use a pertrained model in colab
pretrained = True #@param {type:"boolean"}
pretrained_profile ='hifisinger-v2.1.0'#@param ['hifisinger-v2.1.0', 'diffusion-v2.0.0']

PROFILES = {
  "hifisinger-v2.1.0": {
    "arch": "hifisinger",
    "config": "https://github.com/fishaudio/fish-diffusion/releases/download/v2.1.0/svc_hifisinger_finetune.py",
    "model": "https://github.com/fishaudio/fish-diffusion/releases/download/v2.1.0/hifisinger-pretrained-20230329-540k.ckpt"
  },
  "diffusion-v2.0.0": {
    "arch": "diffusion",
    "config": "https://github.com/fishaudio/fish-diffusion/releases/download/v2.0.0/svc_content_vec_finetune.py",
    "model": "https://github.com/fishaudio/fish-diffusion/releases/download/v2.0.0/content-vec-pretrained-v1.ckpt"
  }
}

#@markdown ---
#@markdown Or bring your own config if you don't want to use pretrained
arch = 'hifisinger'#@param ['diffusion', 'hifisinger']
config_path = ''#@param{type:"string"}
#@markdown Leaving the following field empty will disable pretrain
pretrained_model_path = ''#@param{type:"string"}

if pretrained:
  profile = PROFILES[pretrained_profile]
  arch = profile["arch"]
  config_path = f"configs/svc_{profile['arch']}_finetune.py"
  pretrained_model_path = f"checkpoints/pretrained_{profile['arch']}.ckpt"

  # !wget -q --show-progress "{profile['config']}" -O "/content/fish-diffusion/{config_path}"
  # !wget -q --show-progress "{profile['model']}" -O "/content/fish-diffusion/{pretrained_model_path}"

  print(f"Your config is saved to {config_path}")

# %%
#@title 🎯 Configure Training Steps (Smart Recommendations)
# This cell analyzes your dataset and recommends optimal training steps
# Based on empirical analysis: optimal checkpoints typically appear at
# 7k-8k steps (first peak) and 15k-16k steps (second peak)

import os
import glob
import re

print("=" * 70)
print("TRAINING STEPS CONFIGURATION")
print("=" * 70)

# Count training files
train_path = "/content/fish-diffusion/dataset/train"
if os.path.exists(train_path):
    train_files = [f for f in os.listdir(train_path) if f.endswith('.wav')]
    num_files = len(train_files)

    # Estimate duration (assuming 6-8 second average per file after preprocessing)
    avg_seconds_per_file = 7
    total_minutes = (num_files * avg_seconds_per_file) / 60

    print(f"\n📊 Dataset Analysis:")
    print(f"  • Training files: {num_files}")
    print(f"  • Estimated duration: ~{total_minutes:.0f} minutes")

    # Smart recommendations based on dataset size
    if num_files < 150:
        recommended_steps = 10000
        rationale = "Small dataset - captures first optimal peak (7k-8k)"
        time_estimate = "5-6 hours on T4 GPU"
    elif num_files < 300:
        recommended_steps = 20000
        rationale = "Medium dataset - captures both optimal peaks (7k-8k and 15k-16k)"
        time_estimate = "10-12 hours on T4 GPU"
    elif num_files < 450:
        recommended_steps = 25000
        rationale = "Large dataset - extends beyond second peak for refinement"
        time_estimate = "12-15 hours on T4 GPU"
    else:
        recommended_steps = 30000
        rationale = "Very large dataset - allows extended training"
        time_estimate = "15-18 hours on T4 GPU"

    print(f"\n💡 Recommended Settings:")
    print(f"  • Training steps: {recommended_steps:,}")
    print(f"  • Rationale: {rationale}")
    print(f"  • Estimated time: {time_estimate}")

else:
    print("⚠️ Dataset not found - using default recommendation")
    recommended_steps = 20000
    print(f"\n💡 Default: {recommended_steps:,} steps")

print("\n" + "=" * 70)

# User override option
#@markdown **Override Training Steps** (leave empty to use recommendation):
custom_steps = None #@param {type:"number"}

if custom_steps and custom_steps > 0:
    max_steps = int(custom_steps)
    print(f"✅ Using custom setting: {max_steps:,} steps")
else:
    max_steps = recommended_steps
    print(f"✅ Using recommended setting: {max_steps:,} steps")

print("=" * 70)

# Update config files with selected max_steps
print(f"\n📝 Updating configuration files...")

# Update base trainer config
base_config = "/content/fish-diffusion/configs/_base_/trainers/base.py"
with open(base_config, 'r') as f:
    content = f.read()

content = re.sub(r'max_steps\s*=\s*\d+', f'max_steps={max_steps}', content)

with open(base_config, 'w') as f:
    f.write(content)
print(f"  ✅ Updated {base_config}")

# Update HiFiSinger config
hifisinger_config = f"/content/fish-diffusion/{config_path}"
if os.path.exists(hifisinger_config):
    with open(hifisinger_config, 'r') as f:
        content = f.read()

    content = re.sub(r'max_steps\s*=\s*\d+', f'max_steps={max_steps}', content)

    with open(hifisinger_config, 'w') as f:
        f.write(content)
    print(f"  ✅ Updated {hifisinger_config}")

print("\n" + "=" * 70)
print(f"🎯 TRAINING CONFIGURED FOR {max_steps:,} STEPS")
print("=" * 70)
print(f"\n📈 What to expect:")

# Calculate expected checkpoint count
checkpoint_count = max_steps // 500
print(f"  • Total checkpoints: ~{checkpoint_count} (every 500 steps)")
print(f"  • Best 10 checkpoints will be kept automatically")
print(f"  • Validation every 500 steps for precise peak capture")

# Show when to expect optimal checkpoints
if max_steps >= 8000:
    print(f"\n🏆 Expected optimal checkpoints:")
    print(f"  • First peak: around steps 7,000-8,000")
    if max_steps >= 16000:
        print(f"  • Second peak: around steps 15,000-16,000")

print(f"\n⏱️ Pro tip: Monitor TensorBoard audio samples at these checkpoints!")

# %% [markdown]
# > The project is under active development, please backup your config file
# > The project is under active development, please backup your config file
# > The project is under active development, please backup your config file

# %% [markdown]
# ### Extract Features

# %%
#@title
# !source /content/env/bin/activate;\
conda activate fish_diffusion;\
python tools/preprocessing/extract_features.py --config "{config_path}" --path dataset/valid --clean --no-augmentation;\
python tools/preprocessing/extract_features.py --config "{config_path}" --path dataset/train --clean --num-workers 4

# %% [markdown]
# ## Final Steps

# %%
#@title Training
#@markdown You may want to resume from your previous checkpoint
resume = False #@param {type:"boolean"}
resume_model_path = ''#@param{type:"string"}

logger = 'tensorboard' #@param ['wandb', 'tensorboard']
#@markdown You may continue your wandb experiment by providing the experiment id
resume_id = ''#@param{type:"string"}
#@markdown Point to where you want to save models & logs in GDrive
dest_path = '/content/drive/MyDrive/FishSVC/'#@param{type:"string"}

args = ""
if pretrained_model_path:
  args += f"--pretrain {pretrained_model_path} "

if logger == "tensorboard":
  args += f"--tensorboard "
  # %load_ext tensorboard
  # %tensorboard --logdir .

if resume:
  args += f"--resume {resume_model_path} "
  if logger == "wandb" and resume_id:
    args += f"--resume-id {resume_id} "
if dest_path:
   args += f"--dest-path {dest_path} "

# !source /content/env/bin/activate;\
conda activate fish_diffusion;\
python "tools/{arch}/colab_train.py" --config "{config_path}" {args}

# %% [markdown]
# After training, you can find your checkpoints in `/content/fish-diffusion/logs/HiFiSVC/[VERSION]/checkpoints`, make sure to backup them.

# %% [markdown]
# ### Inference

# %%
#@title Gradio UI
#@markdown You need to run the model_config block before running this one.

#@markdown The checkpoint path you want to use. You can use a folder if you want the code to atutomatically find the latest one
checkpoint_path = "/content/fish-diffusion/logs/HiFiSVC/version_0/checkpoints" #@param {type:"string"}

import yaml

if arch == "hifisinger":
  gradio_config = {
    "readme": "# Fish Diffusion - HiFiSinger Demo 🎤\nGitHub Repo: [fishaudio/fish-diffusion](https://github.com/fishaudio/fish-diffusion) \nTo share a new model, please check out the [Share Your Model](https://huggingface.co/spaces/fishaudio/fish-diffusion/discussions/2) discussion.\n",
    "max_mixing_speakers": 3,
    "models": [
      {
        "name": "demo",
        "config": config_path,
        "checkpoint": checkpoint_path,
        "readme": "This model is pretrained on the Opencpop and M4Singer dataset and fintuned on your dataset.",
      }
    ]
  }

  with open("gradio-config.yaml", "w") as f:
    yaml.dump(gradio_config, f)

  # !source /content/env/bin/activate;\
    conda activate fish_diffusion;\
    python -c 'import gradio;gradio.close_all()';\
    python /content/fish-diffusion/tools/hifisinger/gradio_ui.py \
    --config gradio-config.yaml --share
else:
  # !source /content/env/bin/activate;\
    conda activate fish_diffusion;\
    python tools/diffusion/inference.py \
    --config "{config_path}" --checkpoint "{checkpoint_path}" \
    --gradio --gradio_share

# %% [markdown]
# #### Command Line
# This is not recommanded for beginners, but it gives you more flexibility.

# %%
# !source /content/env/bin/activate;\
    conda activate fish_diffusion;\
    python "tools/{arch}/inference.py" \
    --config "{config_path}" --checkpoint "{checkpoint_path}" \
    --input "input.wav" \
    --output "output.wav" \
    --speaker 0 --pitch_adjust 0
